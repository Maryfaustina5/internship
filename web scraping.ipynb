# %% [markdown]
# Web Scraping Assignment

# %%
1. Question: 1) Write a python program to display all the header tags from wikipedia.org and make data frame.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


url = "https://en.wikipedia.org/wiki/Main_Page"
r = requests.get(url)
soup = BeautifulSoup(r.content, "html.parser")
h = soup.find_all(["h1", "h2", "h3", "h4", "h5", "h6"])
hr = [tag.get_text() for tag in h]
df = pd.DataFrame(hr)
print(df)
# Out:
#                                 0
# 0                       Main Page
# 1            Welcome to Wikipedia
# 2   From today's featured article
# 3                Did you know ...
# 4                     In the news
# 5                     On this day
# 6      From today's featured list
# 7        Today's featured picture
# 8        Other areas of Wikipedia
# 9     Wikipedia's sister projects
# 10            Wikipedia languages

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL for the ICC ODI Men's Team Rankings
team_ranking_url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"

# URL for the ICC ODI Men's Batsmen Rankings
batsmen_ranking_url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"

# URL for the ICC ODI Men's Bowlers Rankings
bowlers_ranking_url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling"

# Function to scrape ranking data and create a DataFrame
def scrape_and_create_dataframe(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='table')
        data = []

        for row in ranking_table.find_all('tr')[1:11]:  # Extract the top 10 records
            cols = row.find_all('td')
            record = [col.text.strip() for col in cols]
            data.append(record)

        headers = ['Rank', 'Team', 'Matches', 'Points', 'Rating']
        df = pd.DataFrame(data, columns=headers)
        return df
# Scrape and create DataFrames for Team Rankings, Batsmen Rankings, and Bowlers Rankings
team_df = scrape_and_create_dataframe(team_ranking_url)
batsmen_df = scrape_and_create_dataframe(batsmen_ranking_url)
bowlers_df = scrape_and_create_dataframe(bowlers_ranking_url)

# Display the DataFrames
print("Top 10 ODI Teams:")
print(team_df)

print("\nTop 10 ODI Batsmen:")
print(batsmen_df)

print("\nTop 10 ODI Bowlers:")
print(bowlers_df)
# Out:
# Top 10 ODI Teams:
#   Rank              Team Matches Points Rating
# 0    1        India\nIND      49  5,839    119
# 1    2    Australia\nAUS      36  4,015    112
# 2    3     Pakistan\nPAK      32  3,525    110
# 3    4  South Africa\nSA      29  3,166    109
# 4    5   New Zealand\nNZ      38  4,007    105
# 5    6      England\nENG      34  3,377     99
# 6    7     Sri Lanka\nSL      43  3,943     92
# 7    8   Bangladesh\nBAN      40  3,574     89
# 8    9  Afghanistan\nAFG      26  2,170     83
# 9   10   West Indies\nWI      38  2,582     68
#
# Top 10 ODI Batsmen:
#                                                 Rank                   Team  \
# 0               1\n                        \n\n\n(0)             Babar Azam
# 1       2\n                                \n\n\n(0)           Shubman Gill
# 2  3\n                                \n\n\n\n\n(...        Quinton de Kock
# 3  4\n                                \n\n\n\n\n(...       Heinrich Klaasen
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL for the ICC Women's ODI Team Rankings
team_ranking_url = "https://www.icc-cricket.com/rankings/womens/team-rankings/odi"

# URL for the ICC Women's ODI Batting Rankings
batsmen_ranking_url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting"

# URL for the ICC Women's ODI All-Rounder Rankings
all_rounder_ranking_url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder"

# Function to scrape ranking data and create a DataFrame
def scrape_and_create_dataframe(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='table')
        data = []

        for row in ranking_table.find_all('tr')[1:11]:  # Extract the top 10 records
            cols = row.find_all('td')
            record = [col.text.strip() for col in cols]
            data.append(record)

        headers = ['Rank', 'Team', 'Matches', 'Points', 'Rating']
        df = pd.DataFrame(data, columns=headers)
        return df
# Scrape and create DataFrames for Women's Team Rankings, Batsmen Rankings, and All-Rounder Rankings
team_df = scrape_and_create_dataframe(team_ranking_url)
batsmen_df = scrape_and_create_dataframe(batsmen_ranking_url)
all_rounder_df = scrape_and_create_dataframe(all_rounder_ranking_url)

# Display the DataFrames
print("Top 10 Women's ODI Teams:")
print(team_df)

print("\nTop 10 Women's ODI Batsmen:")
print(batsmen_df)

print("\nTop 10 Women's ODI All-Rounders:")
print(all_rounder_df)
# Out:
# Top 10 Women's ODI Teams:
#   Rank              Team Matches Points Rating
# 0    1    Australia\nAUS      19  3,084    162
# 1    2      England\nENG      23  2,991    130
# 2    3  South Africa\nSA      21  2,446    116
# 3    4        India\nIND      18  1,745     97
# 4    5   New Zealand\nNZ      21  2,014     96
# 5    6   West Indies\nWI      18  1,610     89
# 6    7     Sri Lanka\nSL       9    714     79
# 7    8   Bangladesh\nBAN      11    816     74
# 8    9     Thailand\nTHA      11    753     68
# 9   10     Pakistan\nPAK      21  1,435     68
#
# Top 10 Women's ODI Batsmen:
#                                             Rank                  Team  \
# 0           1\n                        \n\n\n(0)  Natalie Sciver-Brunt
# 1   2\n                                \n\n\n(0)           Beth Mooney
# 2   3\n                                \n\n\n(0)   Chamari Athapaththu
# 3   4\n                                \n\n\n(0)       Laura Wolvaardt
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the CNBC World News page
url = "https://www.cnbc.com/world/?region=world"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the page content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Initialize empty lists to store data
    headlines = []
    times = []
    news_links = []

    # Find and extract news details
    news_articles = soup.find_all("div", class_="Card-textWrapper")
    for article in news_articles:
        headline = article.find("a", class_="Card-title").text.strip()
        time = article.find("time")['datetime']
        news_link = article.find("a", class_="Card-title")['href']
        headlines.append(headline)
        times.append(time)
        news_links.append(news_link)
# Create a DataFrame
    news_df = pd.DataFrame({
        'Headline': headlines,
        'Time': times,
        'News Link': news_links
    })

    # Display the DataFrame
    print(news_df)

else:
    print("Failed to retrieve the page. Status code:", response.status_code)
# Out:
# Empty DataFrame
# Columns: [Headline, Time, News Link]
# Index: []

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the CNBC World News page
url = "https://www.cnbc.com/world/?region=world"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the page content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Initialize empty lists to store data
    headlines = []
    times = []
    news_links = []

    # Find and extract news details
    news_articles = soup.find_all("div", class_="Card-textWrapper")
    for article in news_articles:
        headline = article.find("a", class_="Card-title").text.strip()
        time = article.find("time")['datetime']
        news_link = article.find("a", class_="Card-title")['href']
        headlines.append(headline)
        times.append(time)
        news_links.append(news_link)

    # Create a DataFrame
    news_df = pd.DataFrame({
        'Headline': headlines,
        'Time': times,
        'News Link': news_links
    })

    # Display the DataFrame
    print(news_df)
else:
    print("Failed to retrieve the page. Status code:", response.status_code)
# Out:
# Empty DataFrame
# Columns: [Headline, Time, News Link]
# Index: []

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the page with most downloaded AI articles
url = "https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the page content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Initialize empty lists to store data
    titles = []
    authors = []
    published_dates = []
    paper_urls = []

    # Find and extract article details
    articles = soup.find_all("li", class_="pod-listing")
    for article in articles:
        title = article.find("a", class_="pod-listing-title").text.strip()
        author = article.find("a", class_="pod-listing-author-name").text.strip()
        date = article.find("div", class_="pod-listing-body").find("p").text.strip()
        url = article.find("a", class_="pod-listing-title")['href']
        titles.append(title)
        authors.append(author)
        published_dates.append(date)
        paper_urls.append(url)

    # Create a DataFrame
    article_df = pd.DataFrame({
        'Paper Title': titles,
        'Authors': authors,
        'Published Date': published_dates,
        'Paper URL': paper_urls
    })
    
     # Display the DataFrame
    print(article_df)

else:
    print("Failed to retrieve the page. Status code:", response.status_code)
# Out:
# Failed to retrieve the page. Status code: 500
